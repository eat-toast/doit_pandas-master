# %% [markdown]
# <a href="https://colab.research.google.com/github/eat-toast/doit_pandas-master/blob/master/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4-1 데이터 시각화가 필요한 이유

# %%
# 앤스콥 4분할 그래프.. 
# 회귀분석 책에 나와있는 예제가 앤스콤(Frank Anscombe)라는 사람이 만든거구나..
# 더 자세한 내용은 아래 예제를 통해 알아보자

# %% [markdown]
# ### 1. 엔스콥 데이터 집합 불러오기

# %%
import seaborn as sns

# %%
anscombe = sns.load_dataset('anscombe')
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# ### 2. mapplotlib 라이브러리로 그래프 그리기

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']

# %%
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
# plt는 기본으로 선이 나오기 때문에 'o'라는 옵션을 지정해 줘야 점으로 나온다.
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# ### 한번에 4개의 그래프 그리기

# %%
# R에서는 par(mfrow=c(2,2))로 했는데.. python은?

# %%
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# %%
# 그래프 격자를 만들기 위해 기본 틀을 만든다.
fig = plt.figure()

# 그 다음 add_subplot()으로 그래프 격자를 그린다.
# 기본 틀 (fig)에 격자를 추가한다는 기분으로 add_subplot을 사용하면 된다. 

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
# 이제 plot메소드에 전달하여 그래프를 그리면 된다. 
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %%
# 각각의 그래프에 제목을 추가해보자
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')
fig

# %%
# 기본틀 (fig)에도 제목 추가하기
fig.suptitle('Anscombe Data')
fig

# %%
# 그림이 겹쳐 보이기 때문에 조절을 한다.
fig.tight_layout()
fig

# %% [markdown]
# # 4-2 matplotlib 자유자대로 사용하기

# %%
# tips에는 팁에 관련된 데이터가 들어있다.
# 지불금액, 팁, 성별, 흡연유무, 요일, 시간, 진체인원
tips = sns.load_dataset('tips')
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Hist

# %%
# 기본틀(fig)를 마련하고 그래프 격자(axes1)을 구성
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)

# hist 메소드에 특정 열을 전달하면 hist가 완성
axes1.hist(tips['total_bill'], bins = 10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Freq')
axes1.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ### # 산점도 그리기

# %%
# 산점도 그리기
scatter_plot = plt.figure() # 기본틀 만들기
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot og Total Bill vs Tip')
axes1.set_xlabel('Total BIll')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### 박스 플랏

# %%
# 박스 플랏
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([ tips[tips['sex'] == 'Female']['tip'],
                tips[tips['sex'] == 'Male']['tip']],
              labels = ['Female', 'Male'] )

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot og Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot og Tips by Sex')

# %% [markdown]
# ### apply 활용

# %%
def recode_sex(sex):
  if sex == 'Female':
    return 0
  else:
    return 1

# %%
# apply에 함수를 넣는것은 R과 동일한데 사용하는 구조가 다르네.. 
# Series.apply(함수)
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
# 산점도를 그릴 때, 점의 크기도 지정할 수 있다.
# 이번에는 테이블당 인원수도 점의 크기로 그려본다.
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
  x = tips['total_bill'],
  y = tips['tip'],
  s = tips['size']*20,
  c = tips['sex_color'],
  alpha = 0.5)

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # 4-3 seaborn 자유자재로 사용하기

# %%
# matplot보다 깔끔한 그래프를 그릴 수 있다. 
# R에서의 ggplot같은 느낌스트

import seaborn as sns
tips = sns.load_dataset('tips')

# %%
# ax에 자꾸 대입하는 이유는 무엇일까
# ax = plt.subplot()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %% [markdown]
# ### 산점도 그리기

# %%
ax = sns.regplot(x = 'total_bill', y='tip', data = tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = sns.regplot(x = 'total_bill', y='tip', data = tips, fit_reg = False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 산점도와 히스트 한번에!!

# %%
joint = sns.jointplot(x = 'total_bill', y = 'tip', data = tips)
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize = 10, y = 1.03)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
joint = sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'hex')
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize = 10, y = 1.03)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# ### 2차원 밀집도 그리기

# %%
ax = sns.kdeplot(data = tips['total_bill'],
                  data2 = tips['tip'] ) # shade = True
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %% [markdown]
# ### bar그래프 그리기

# %%
ax = sns.barplot(x = 'time', y='total_bill', data = tips)

# %% [markdown]
# ### 박스 플랏 그리기

# %%
ax = sns.boxplot(x = 'time', y= 'total_bill', data = tips)

# %% [markdown]
# ### 바이올린 그래프

# %%
ax = sns.violinplot(x = 'time', y='total_bill', data = tips)

# %% [markdown]
# ### 관계 그래프 그리기

# %%
fig = sns.pairplot(tips)

# %%
# pairplot은 위 아래로 같은 그림이다. 
# 이를 옵션으로 변경할 수 있다.
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:1000: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ### 그래프 색상 변경

# %%
ax = sns.violinplot(x = 'time', y='total_bill', hue = 'sex', data = tips, split = True)

# %%
scatter = sns.lmplot(x = 'total_bill', y='tip', data = tips, hue = 'sex') # , fit_reg = False

# %%
fig = sns.pairplot(tips, hue = 'sex')

# %% [markdown]
# ### 다른점으로 표기하기 - makers

# %%
scatter = sns.lmplot(x = 'total_bill', y='tip', data = tips, hue = 'sex',
                    markers = ['o', 'x'], scatter_kws = {'s': tips['size']*10})

# %% [markdown]
# ### lmplot 메소드로 4개의 데이터 그룹에 대한 그래프 한번에 그리기

# %%
# 4개의 그룹에 대한 데이터가 한번에 그름으로 표기 되었다. 
# 어떻게 하면 분리 할 수 있을까?
anscombe_plot = sns.lmplot(x='x', y='y', data = anscombe, fit_reg = True)

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data = anscombe, fit_reg = True,
                          col='dataset', col_wrap=2)

# %% [markdown]
# ### FacetGrid ★★

# %%
# col의 위치에 구분할 변수 입력
# map에 사용할 plot, 살펴볼 변수 순서로 입력
facet = sns.FacetGrid(tips, col='time')
facet.map(sns.distplot, 'total_bill', rug = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
facet = sns.FacetGrid(tips, col='day', hue = 'sex')
facet = facet.map(sns.regplot, 'total_bill', 'tip')
facet = facet.add_legend()

# %%
# 이번에는 더 많은 변수를 사용하여 그래프를 그려 보자.
# time, smoker
facet = sns.FacetGrid(tips, col='time',row='smoker', hue = 'sex')
facet = facet.map(sns.regplot, 'total_bill', 'tip')

# %% [markdown]
# # 4-4 데이터 프레임과 시리즈로 그래프 그리기

# %%
ax = tips['total_bill'].plot.hist()

# %%
fig = plt.figure()
axe1 = fig.add_subplot(1,1,1)
axe1 = axe1.hist('total_bill', bins = 20)

# %%
tips[['total_bill', 'tip']].plot.hist(alpha = 0.5, bins=40)

# %% [markdown]
# # 4-5 seaborn 라이브러리로 그래프 스타일 설정하기

# %%
fig, ax = plt.subplots()
ax = sns.violinplot(x = 'time', y = 'total_bill', data = tips, hue = 'sex', split = 'True')

# %%
# 원하는 데로 되지 않네
facet = sns.FacetGrid(tips, col='time', hue = 'sex')
facet = facet.map(sns.violinplot, 'total_bill' )

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
ax = sns.violinplot(x = 'time', y = 'total_bill', data = tips, hue = 'sex', split = 'True')
